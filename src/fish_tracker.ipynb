# %%
import os
import cv2
import numpy as np
import pandas as pd
import math
import random

from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
from scipy.spatial.transform import Rotation
from tqdm import tqdm,trange

from numpy.linalg import inv

import imgaug.augmenters as iaa

from lib.utils.tracker_new import Sort as Tracker

# %%
def read_calib(path):
    with open(path, 'r') as f:
        lines = f.readlines()
        P2 = np.array(lines[2].strip().split(' ')[1:], dtype=np.float32).reshape(3, 4)
        
    return P2

def get_corners(data,rx=0,ry=0,rz=0,x=None,y=None,z=None):
    
    x = data['x'] if x == None else x
    y = data['y'] if y == None else y
    z = data['z'] if z == None else z

    R = Rotation.from_euler('zxy', [rz,rx,ry], degrees=False).as_matrix()
    
#     R = roty(data['yaw'])
    l = float(data['l'])
    w = float(data['w'])
    h = float(data['h'])
    
    x_corners = [l / 2, l / 2, -l / 2, -l / 2, l / 2, l / 2, -l / 2, -l / 2]
#     y_corners = [0,0,0,0,h,h,h,h]
    y_corners = [h/2,h/2,h/2,h/2,-h/2,-h/2,-h/2,-h/2]
    z_corners = [w / 2, -w / 2, -w / 2, w / 2, w / 2, -w / 2, -w / 2, w / 2]
    
    corners = np.dot(R,np.vstack([x_corners, y_corners, z_corners]))


#     translate from origin 
    corners[0,:] = corners[0,:] + x
    corners[1,:] = corners[1,:] + y
    corners[2,:] = corners[2,:] + z
#     corners = np.dot(R,corners)
    return corners

def project_3d(P,corner):
    conn = np.concatenate((corner.T, np.ones((8, 1))), axis=1)
    corners_img_before = np.matmul(conn, P.T)
    corners_img = corners_img_before[:, :2] / corners_img_before[:, 2][:, None]
    
    return corners_img

def random_color():
    r = random.randint(0, 255)
#     g = random.randint(0, 255)
#     b = random.randint(0, 255)
    rand_color = (255, 0, 0)
    return rand_color

def plot_img(plot,pts):
    
    color = random_color()
    # TOP SIDE EFGH
    plot = draw_line(plot,pts[4],pts[5],color=color)
    plot = draw_line(plot,pts[5],pts[6],color=color)
    plot = draw_line(plot,pts[6],pts[7],color=color)
    plot = draw_line(plot,pts[7],pts[4],color=color)

    # BOT SIDE ABCD
#     plot = draw_line(plot,pts[0],pts[1],color=(255,0,0))
#     plot = draw_line(plot,pts[1],pts[2],color=(255,0,0))
#     plot = draw_line(plot,pts[2],pts[3],color=(255,0,0))
#     plot = draw_line(plot,pts[3],pts[0],color=(255,0,0))
    
    plot = draw_line(plot,pts[0],pts[1],color=color)
    plot = draw_line(plot,pts[1],pts[2],color=color)
    plot = draw_line(plot,pts[2],pts[3],color=color)
    plot = draw_line(plot,pts[3],pts[0],color=color)

    # TIANG AE BF CG DH
    plot = draw_line(plot,pts[0],pts[4],color=color)
    plot = draw_line(plot,pts[1],pts[5],color=color)
    plot = draw_line(plot,pts[2],pts[6],color=color)
    plot = draw_line(plot,pts[3],pts[7],color=color)
    
#     plot = draw_line(plot,pts[0],pts[5],color=(255,0,0))
#     plot = draw_line(plot,pts[4],pts[1],color=(255,0,0))
    return plot

def draw_line(img,ptA,ptB,color=(255, 0, 0)):
    start_point = (int(ptA[0]),int(ptA[1]))
    end_point = (int(ptB[0]),int(ptB[1]))
    thickness = 1
    
    img = cv2.line(img, start_point, end_point, color, thickness)
    return img

def draw_rect(img,data,color=(0, 255, 0)):
    x0,y0 = int(data['xmin']),int(data['ymin'])
    x1,y1 = int(data['xmax']),int(data['ymax'])
    
    img = cv2.rectangle(img,(x0,y0),(x1,y1), color, 2)
    return img

def roty(t):
    c = np.cos(t)
    s = np.sin(t)
    return np.array([[c, 0, s], 
                     [0, 1, 0], 
                     [-s, 0, c]])

def calc_theta_ray(width, xmin,xmax, proj_matrix,is_y=False):
#     if is_y:
#         temp = xmin
#         xmin = 512-xmax
#         xmax = 512-temp
    
    fovx = 2 * np.arctan(width / (2 * proj_matrix[0][0]))
    center = xmin + abs(xmax-xmin)/2
    
    center = width - center if is_y else center
    
    dx = center - (width / 2)

    mult = 1
    if dx < 0:
        mult = -1
    dx = abs(dx)
    angle = np.arctan( (2*dx*np.tan(fovx/2)) / width )
    angle = angle * mult

    angle = fovx/2 - angle
    return angle

def get_theta(width,xmin,xmax,P,is_y=False):
    center = xmin + abs(xmax-xmin)/2
    F = P[0][0]
    dx = center - (width/2)
    dx = width - dx if is_y else dx
    theta = np.arctan(dx/F)
    
    theta = theta + np.pi/2 if is_y else theta
    return theta

def calc_theta_ray(width, xmin,xmax, proj_matrix,is_y=False):
    
    fovx = 2 * np.arctan(width / (2 * proj_matrix[0][0]))
    center = xmin + abs(xmax-xmin)/2
    
    center = width - center if is_y else center
    
    dx = center - (width / 2)

    mult = 1
    if dx < 0:
        mult = -1
    dx = abs(dx)
    angle = np.arctan( (2*dx*np.tan(fovx/2)) / width )
    angle = angle * mult

    angle = fovx/2 - angle
    return angle

def calc_theta_ray_center(width, center, proj_matrix,is_y=False):
    fovx = 2 * np.arctan(width / (2 * proj_matrix[0][0]))
    
    center = width - center if is_y else center
    
    dx = center - (width / 2)

    mult = 1
    if dx < 0:
        mult = -1
    dx = abs(dx)
    angle = np.arctan( (2*dx*np.tan(fovx/2)) / width )
    angle = angle * mult

    angle = fovx/2 - angle
    return angle

def get_ry(img_size,t):
    return (calc_theta_ray_center(img_size,t['cx'],P) + t['alphax'])

def get_rx(img_size,t):
    return -(calc_theta_ray_center(img_size,t['cy'],P,is_y=True) + t['alphay']) * -1

def get_xy(ann,center,P,c=0):
    
    center = np.array(center).reshape((1,2))
    depth = np.array(ann['z']).reshape(1,1)

    return imagetocamera(center,depth,P)

def imagetocamera(points, depth, projection):
    """
    points: (N, 2), N points on X-Y image plane
    depths: (N,), N depth values for points
    projection: (3, 4), projection matrix
    corners: (N, 3), N points on X(right)-Y(down)-Z(front) camera coordinate
    """
    assert points.shape[1] == 2, "Shape ({}) not fit".format(points.shape)

    corners = np.hstack([points, np.ones(
        (points.shape[0], 1))]).dot(inv(projection[:, 0:3]).T)
    assert np.allclose(corners[:, 2], 1)
    corners *= depth.reshape(-1, 1)

    return list(corners[0])

# %%
def bbox_iou(boxA, boxB):
    # boxA and boxB are lists or tuples of (x1, y1, x2, y2)
    # representing the top-left corner coordinates (x1, y1)
    # and the bottom-right corner coordinates (x2, y2) of the boxes

    # determine the coordinates of the intersection rectangle
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])

    # compute the area of intersection rectangle
    intersection_area = max(0, xB - xA + 1) * max(0, yB - yA + 1)

    # compute the area of both the prediction and ground-truth
    # rectangles
    boxA_area = (boxA[2] - boxA[0] + 1) * (boxA[3] - boxA[1] + 1)
    boxB_area = (boxB[2] - boxB[0] + 1) * (boxB[3] - boxB[1] + 1)

    # compute the intersection over union by taking the
    # intersection area and dividing it by the sum of prediction
    # + ground-truth areas - the intersection area
    iou = intersection_area / float(boxA_area + boxB_area - intersection_area)

    # return the intersection over union value
    return iou

# %%
BASE_DIR_calib = '/home/alfin/Documents/deep_learning/production/centernet_3d_fish/'
# BASE_DIR = BASE_DIR_calib
BASE_DIR = '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/'

# IMG_DIR = os.path.join(BASE_DIR,'trainval/')
IMG_DIR = os.path.join(BASE_DIR,'output_3/')
INF_DIR = os.path.join(BASE_DIR,'label_inference/')
CALIB_DIR = os.path.join(BASE_DIR_calib,'data/')

data_path = [{'img':IMG_DIR+img,'inf':INF_DIR+inf
             } for img,inf in 
             zip(sorted(os.listdir(IMG_DIR)),
                 sorted([x for x in os.listdir(INF_DIR) if not x.endswith('track.txt')])
                )]

calib_path = os.path.join(CALIB_DIR,'000000.txt')

# %%
data_path
# Out:
# [{'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000000.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000000.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000001.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000001.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000002.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000002.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000003.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000003.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000004.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000004.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000005.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000005.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000006.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000006.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000007.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000007.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000008.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000008.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000009.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000009.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000010.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000010.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000011.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000011.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000012.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000012.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000013.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000013.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000014.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000014.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000015.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000015.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000016.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000016.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000017.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000017.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000018.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000018.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000019.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000019.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000020.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000020.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000021.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000021.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000022.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000022.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000023.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000023.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000024.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000024.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000025.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000025.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000026.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000026.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000027.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000027.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000028.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000028.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000029.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000029.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000030.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000030.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000031.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000031.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000032.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000032.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000033.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000033.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000034.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000034.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000035.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000035.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000036.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000036.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000037.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000037.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000038.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000038.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000039.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000039.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000040.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000040.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000041.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000041.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000042.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000042.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000043.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000043.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000044.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000044.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000045.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000045.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000046.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000046.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000047.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000047.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000048.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000048.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000049.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000049.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000050.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000050.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000051.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000051.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000052.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000052.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000053.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000053.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000054.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000054.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000055.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000055.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000056.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000056.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000057.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000057.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000058.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000058.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000059.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000059.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000060.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000060.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000061.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000061.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000062.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000062.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000063.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000063.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000064.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000064.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000065.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000065.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000066.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000066.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000067.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000067.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000068.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000068.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000069.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000069.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000070.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000070.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000071.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000071.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000072.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000072.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000073.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000073.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000074.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000074.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000075.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000075.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000076.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000076.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000077.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000077.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000078.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000078.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000079.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000079.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000080.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000080.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000081.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000081.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000082.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000082.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000083.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000083.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000084.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000084.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000085.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000085.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000086.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000086.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000087.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000087.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000088.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000088.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000089.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000089.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000090.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000090.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000091.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000091.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000092.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000092.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000093.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000093.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000094.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000094.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000095.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000095.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000096.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000096.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000097.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000097.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000098.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000098.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000099.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000099.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000100.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000100.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000101.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000101.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000102.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000102.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000103.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000103.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000104.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000104.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000105.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000105.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000106.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000106.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000107.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000107.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000108.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000108.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000109.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000109.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000110.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000110.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000111.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000111.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000112.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000112.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000113.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000113.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000114.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000114.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000115.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000115.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000116.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000116.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000117.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000117.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000118.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000118.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000119.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000119.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000120.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000120.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000121.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000121.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000122.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000122.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000123.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000123.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000124.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000124.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000125.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000125.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000126.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000126.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000127.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000127.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000128.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000128.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000129.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000129.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000130.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000130.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000131.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000131.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000132.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000132.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000133.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000133.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000134.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000134.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000135.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000135.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000136.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000136.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000137.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000137.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000138.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000138.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000139.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000139.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000140.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000140.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000141.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000141.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000142.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000142.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000143.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000143.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000144.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000144.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000145.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000145.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000146.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000146.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000147.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000147.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000148.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000148.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000149.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000149.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000150.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000150.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000151.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000151.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000152.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000152.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000153.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000153.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000154.jpg',
# ...
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000248.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000249.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000249.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000250.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000250.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000251.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000251.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000252.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000252.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000253.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000253.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000254.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000254.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000255.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000255.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000256.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000256.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000257.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000257.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000258.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000258.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000259.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000259.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000260.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000260.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000261.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000261.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000262.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000262.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000263.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000263.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000264.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000264.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000265.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000265.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000266.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000266.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000267.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000267.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000268.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000268.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000269.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000269.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000270.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000270.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000271.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000271.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000272.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000272.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000273.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000273.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000274.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000274.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000275.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000275.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000276.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000276.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000277.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000277.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000278.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000278.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000279.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000279.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000280.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000280.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000281.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000281.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000282.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000282.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000283.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000283.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000284.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000284.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000285.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000285.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000286.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000286.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000287.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000287.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000288.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000288.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000289.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000289.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000290.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000290.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000291.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000291.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000292.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000292.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000293.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000293.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000294.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000294.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000295.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000295.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000296.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000296.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000297.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000297.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000298.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000298.txt'},
#  {'img': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/output_3/000299.jpg',
#   'inf': '/home/alfin/Documents/deep_learning/fish_conversion/data/20221121_centernet_rxry/KITTI/detection/training/sample_video/label_inference/000299.txt'}]

# %%
len(data_path)
# Out:
# 300

# %%
img_input_size = (512,512)

tracker = Tracker()
inf_header = ['h','w','l','z','alphax','alphay','conf','idx','cx','cy','xmin','ymin','xmax','ymax','id']

for j,data in tqdm(enumerate(data_path[:])):
#     try:
    tracking_result = list()
    ann = pd.read_csv(data['inf'],sep = ' ',names=inf_header)

    P = read_calib(calib_path)
    detections = []
    
    for i in range(len(ann)):
        label = ann.iloc[i]

        label_dict = label.to_dict()
        label_dict['id'] = 0
        
        xmin = label['xmin']
        ymin = label['ymin']
        xmax = label['xmax']
        ymax = label['ymax']
        
#         center = (int(label['cx']),int(label['cy']))
#         x,y,z = get_xy(label,center,P)

#         ry = get_ry(img_input_size[0],label)
#         rx = get_rx(img_input_size[1],label)
#         rz = 0

#         cor = get_corners(label,rx,ry,rz,x=x,y=y,z=z)

#         pts = project_3d(P,cor)

#         xs = [p[0] for p in pts]
#         ys = [p[1] for p in pts]

#         xmin = int(min(xs))
#         ymin = int(min(ys))
#         xmax = int(max(xs))
#         ymax = int(max(ys))

        detections.append([xmin,ymin,xmax,ymax,label['conf'],label_dict])
    
    if len(detections)==0:
        continue
    detections_np = np.array([d[:5] for d in detections])
    track_ids = tracker.update(detections_np)
#     print(track_ids)
    for t in track_ids:
        box = [0,0,0,0, 0, None]
        
        for d in detections:
            if (bbox_iou(d[:5],t[:5])) > box[4]:
                box = d
                d[-1]['id'] = int(t[-1])

        tracking_result.append(box[-1])
    
#     print(tracking_result)
    df = pd.DataFrame(tracking_result)
    if len(df>0):
        df = df[['h','w','l','z','alphax','alphay','conf','idx','cx','cy','xmin','ymin','xmax','ymax','id']]
    save_path = os.path.splitext(data['inf'])[0]+'_track.txt'
    df.to_csv(save_path,header=False,sep=' ',index=False)
# Out:
# 300it [00:01, 158.77it/s]

# %%
df
# Out:
#            h         w         l         z    alphax    alphay      conf  \
# 0   0.133950  0.061091  0.307553  1.787999  5.283892  5.579156  0.956417
# 1   0.144823  0.065895  0.332498  1.157228  0.214040  5.744151  0.991570
# 2   0.154706  0.070251  0.355632  2.221949  5.761298  5.826317  0.844476
# 3   0.158302  0.072108  0.363932  1.713391  2.073165  5.514184  0.714544
# 4   0.144823  0.065895  0.332498  1.157228  0.214040  5.744151  0.991570
# 5   0.151973  0.069223  0.348819  1.093937  1.623867  5.252581  0.973411
# 6   0.153597  0.069972  0.352853  1.415655  1.662991  4.729012  0.964326
# 7   0.151973  0.069223  0.348819  1.093937  1.623867  5.252581  0.973411
# 8   0.149350  0.067838  0.342891  1.566285  1.848637  4.600142  0.919595
# 9   0.151973  0.069223  0.348819  1.093937  1.623867  5.252581  0.973411
# 10  0.153430  0.069963  0.352503  1.186241  3.092076  5.319581  0.483628
# 11  0.147756  0.067021  0.339061  0.770727  1.525429  5.765335  0.954153
#
#       idx     cx     cy   xmin   ymin   xmax   ymax   id
# 0   299.0  164.0  237.0  137.0  225.0  189.0  247.0  804
# 1   299.0  224.0  143.0  200.0  103.0  252.0  172.0  747
# 2   299.0  164.0  160.0  144.0  144.0  184.0  174.0  802
# 3   299.0  253.0  376.0  221.0  358.0  284.0  395.0  798
# 4   299.0  224.0  143.0  200.0  103.0  252.0  172.0  747
# 5   299.0  357.0  267.0  335.0  244.0  374.0  293.0  679
# 6   299.0  320.0  339.0  291.0  316.0  344.0  366.0  710
# 7   299.0  357.0  267.0  335.0  244.0  374.0  293.0  679
# 8   299.0  324.0  316.0  294.0  299.0  351.0  335.0  710
# 9   299.0  357.0  267.0  335.0  244.0  374.0  293.0  679
# 10  299.0  486.0  276.0  437.0  256.0  538.0  296.0  607
# 11  299.0  425.0  187.0  391.0  132.0  478.0  221.0  577

# %%
tracking_result
# Out:
# [{'h': 0.13395005,
#   'w': 0.061091475,
#   'l': 0.30755287,
#   'z': 1.7879989,
#   'alphax': 5.283892,
#   'alphay': 5.5791564,
#   'conf': 0.95641655,
#   'idx': 299.0,
#   'cx': 164.0,
#   'cy': 237.0,
#   'xmin': 137.0,
#   'ymin': 225.0,
#   'xmax': 189.0,
#   'ymax': 247.0,
#   'id': 804},
#  {'h': 0.14482263,
#   'w': 0.06589491,
#   'l': 0.3324985,
#   'z': 1.1572275,
#   'alphax': 0.21403961,
#   'alphay': 5.744151,
#   'conf': 0.9915697,
#   'idx': 299.0,
#   'cx': 224.0,
#   'cy': 143.0,
#   'xmin': 200.0,
#   'ymin': 103.0,
#   'xmax': 252.0,
#   'ymax': 172.0,
#   'id': 747},
#  {'h': 0.15470637,
#   'w': 0.07025142,
#   'l': 0.35563198,
#   'z': 2.221949,
#   'alphax': 5.7612977,
#   'alphay': 5.826317,
#   'conf': 0.84447557,
#   'idx': 299.0,
#   'cx': 164.0,
#   'cy': 160.0,
#   'xmin': 144.0,
#   'ymin': 144.0,
#   'xmax': 184.0,
#   'ymax': 174.0,
#   'id': 802},
#  {'h': 0.15830201,
#   'w': 0.07210832,
#   'l': 0.36393234,
#   'z': 1.7133911,
#   'alphax': 2.0731647,
#   'alphay': 5.514184,
#   'conf': 0.71454436,
#   'idx': 299.0,
#   'cx': 253.0,
#   'cy': 376.0,
#   'xmin': 221.0,
#   'ymin': 358.0,
#   'xmax': 284.0,
#   'ymax': 395.0,
#   'id': 798},
#  {'h': 0.14482263,
#   'w': 0.06589491,
#   'l': 0.3324985,
#   'z': 1.1572275,
#   'alphax': 0.21403961,
#   'alphay': 5.744151,
#   'conf': 0.9915697,
#   'idx': 299.0,
#   'cx': 224.0,
#   'cy': 143.0,
#   'xmin': 200.0,
#   'ymin': 103.0,
#   'xmax': 252.0,
#   'ymax': 172.0,
#   'id': 747},
#  {'h': 0.15197328,
#   'w': 0.06922301,
#   'l': 0.3488186,
#   'z': 1.0939367,
#   'alphax': 1.623867,
#   'alphay': 5.252581,
#   'conf': 0.97341114,
#   'idx': 299.0,
#   'cx': 357.0,
#   'cy': 267.0,
#   'xmin': 335.0,
#   'ymin': 244.0,
#   'xmax': 374.0,
#   'ymax': 293.0,
#   'id': 679},
#  {'h': 0.153597,
#   'w': 0.069972225,
#   'l': 0.3528532,
#   'z': 1.4156547,
#   'alphax': 1.6629912,
#   'alphay': 4.7290125,
#   'conf': 0.9643265,
#   'idx': 299.0,
#   'cx': 320.0,
#   'cy': 339.0,
#   'xmin': 291.0,
#   'ymin': 316.0,
#   'xmax': 344.0,
#   'ymax': 366.0,
#   'id': 710},
#  {'h': 0.15197328,
#   'w': 0.06922301,
#   'l': 0.3488186,
#   'z': 1.0939367,
#   'alphax': 1.623867,
#   'alphay': 5.252581,
#   'conf': 0.97341114,
#   'idx': 299.0,
#   'cx': 357.0,
#   'cy': 267.0,
#   'xmin': 335.0,
#   'ymin': 244.0,
#   'xmax': 374.0,
#   'ymax': 293.0,
#   'id': 679},
#  {'h': 0.14935035,
#   'w': 0.06783812,
#   'l': 0.34289116,
#   'z': 1.5662849,
#   'alphax': 1.8486375,
#   'alphay': 4.6001425,
#   'conf': 0.9195953,
#   'idx': 299.0,
#   'cx': 324.0,
#   'cy': 316.0,
#   'xmin': 294.0,
#   'ymin': 299.0,
#   'xmax': 351.0,
#   'ymax': 335.0,
#   'id': 710},
#  {'h': 0.15197328,
#   'w': 0.06922301,
#   'l': 0.3488186,
#   'z': 1.0939367,
#   'alphax': 1.623867,
#   'alphay': 5.252581,
#   'conf': 0.97341114,
#   'idx': 299.0,
#   'cx': 357.0,
#   'cy': 267.0,
#   'xmin': 335.0,
#   'ymin': 244.0,
#   'xmax': 374.0,
#   'ymax': 293.0,
#   'id': 679},
#  {'h': 0.15343031,
#   'w': 0.0699627,
#   'l': 0.35250312,
#   'z': 1.1862411,
#   'alphax': 3.0920758,
#   'alphay': 5.3195806,
#   'conf': 0.48362795,
#   'idx': 299.0,
#   'cx': 486.0,
#   'cy': 276.0,
#   'xmin': 437.0,
#   'ymin': 256.0,
#   'xmax': 538.0,
#   'ymax': 296.0,
#   'id': 607},
#  {'h': 0.14775577,
#   'w': 0.067020915,
#   'l': 0.33906102,
#   'z': 0.7707269,
#   'alphax': 1.5254289,
#   'alphay': 5.7653346,
#   'conf': 0.954153,
#   'idx': 299.0,
#   'cx': 425.0,
#   'cy': 187.0,
#   'xmin': 391.0,
#   'ymin': 132.0,
#   'xmax': 478.0,
#   'ymax': 221.0,
#   'id': 577}]
